# %%
# Vizuelna podešavanja okruženja (samo razvuče notebook na širinu ekrana)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import networkx as nx

input_path = "models/model_all_years.gml"
G = nx.read_gml(input_path)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 581
# Number of edges: 5330
# Average degree:  18.3477

# %%
import pandas as pd
dataPath = "data/atp_matches_2018.csv"
matches2018 = pd.read_csv(dataPath)

dataPath = "data/atp_matches_2019.csv"
matches2019 = pd.read_csv(dataPath)

dataPath = "data/atp_matches_2020.csv"
matches2020 = pd.read_csv(dataPath)

# %% [markdown]
# 3. pitanje

# %%
players = G.nodes()
for player in players:
    mask_davis_cup = ((matches2018['winner_id'] == int(player)) | (matches2018['loser_id'] == int(player))) & (matches2018['tourney_id'].str.startswith("2018-M-DC"))
    mask = ((matches2018['winner_id'] == int(player)) | (matches2018['loser_id'] == int(player))) & (~matches2018['tourney_id'].str.startswith("2018-M-DC"))
    
    tourneys = matches2018[mask]
    num2018 = tourneys[['tourney_id']].nunique()['tourney_id']
   
    if mask_davis_cup.any():
        num2018 += 1
    G.nodes()[player]['tourneys_number2018'] = int(num2018)
    
    mask_davis_cup = ((matches2019['winner_id'] == int(player)) | (matches2019['loser_id'] == int(player))) & (matches2019['tourney_id'].str.startswith("2019-M-DC"))
    mask = ((matches2019['winner_id'] == int(player)) | (matches2019['loser_id'] == int(player))) & (~matches2019['tourney_id'].str.startswith("2019-M-DC"))
    
    tourneys = matches2019[mask]
    num2019 = tourneys[['tourney_id']].nunique()['tourney_id']
    if mask_davis_cup.any():
        num2019 += 1
    G.nodes()[player]['tourneys_number2019'] = int(num2019)
    
    mask_davis_cup = ((matches2020['winner_id'] == int(player)) | (matches2020['loser_id'] == int(player))) & (matches2020['tourney_id'].str.startswith("2020-M-DC"))
    mask = ((matches2020['winner_id'] == int(player)) | (matches2020['loser_id'] == int(player))) & (~matches2020['tourney_id'].str.startswith("2020-M-DC"))
    
    tourneys = matches2020[mask]
    num2020 = tourneys[['tourney_id']].nunique()['tourney_id']
    if mask_davis_cup.any():
        num2020 += 1
    G.nodes()[player]['tourneys_number2020'] = int(num2020)
    
    G.nodes()[player]['tourneys_number'] = int(num2018 + num2019 + num2020)

# %%
output_path = "models/model_all_years_tasks.gml"
nx.write_gml(G, output_path)

# %% [markdown]
# 4. pitanje

# %%
G1 = nx.Graph()

ego0 = nx.ego_graph(G, '104655')
ego5 = nx.ego_graph(G, '100644')
ego3 = nx.ego_graph(G, '111575')
ego9 = nx.ego_graph(G, '105138')
ego21 = nx.ego_graph(G, '106043')
ego20 = nx.ego_graph(G, '105311')

set_players = set(list(ego0)).union(set(list(ego5)).union(set(list(ego3)).union(set(list(ego9)).union(set(list(ego21)).union(set(list(ego20)))))))
print(len(set_players))
# Out:
# 218

# %% [markdown]
# 10. pitanje

# %%
r_country = nx.attribute_assortativity_coefficient(G, "country")
r_weight = nx.degree_assortativity_coefficient(G, weight='weight')
r_rank = nx.attribute_assortativity_coefficient(G, "rank")

print(f"Koeficijent asortativnosti na osnovu zemlje porekla čvora: {r_country}")
print(f"Koeficijent asortativnosti na osnovu težinskog stepena čvora: {r_weight}")
print(f"Koeficijent asortativnosti na osnovu rejtinga čvora: {r_rank}")

player_id, clustering_coef = zip(*nx.clustering(G, weight = "weight").items())

not_zero = [(id_p, cc)  for id_p, cc in zip(player_id, clustering_coef) if cc > 0]

df = pd.DataFrame(not_zero, columns = ["id", "cc"])
df.sort_values('cc', ascending = False, inplace = True)

max_lokalni_stepen_klasterisanja = max(clustering_coef)

prosecni_stepen_klasterisanja = nx.average_clustering(G, weight = "weight", count_zeros = False)

print(f"Max lokalni cc: {max_lokalni_stepen_klasterisanja}")
print(f"Prosečan cc: {prosecni_stepen_klasterisanja}")
print("Lokalni stepeni klasterisanja koji nisu nula:")
for row in df.itertuples():
    if G.nodes[row[1]]['tourneys_number'] > 20:
        print('{0:10s} {1:15s} {2:15s} ({3}) => {4:5f}'.format(row[1], G.nodes[row[1]]['first_name'], G.nodes[row[1]]['last_name'], G.nodes[row[1]]['rank'], row[2]))
# Out:
# Koeficijent asortativnosti na osnovu zemlje porekla čvora: 0.009843043206048575
# Koeficijent asortativnosti na osnovu težinskog stepena čvora: 0.14652712553286887
# Koeficijent asortativnosti na osnovu rejtinga čvora: -0.003844501509719885
# Max lokalni cc: 0.16508715292071477
# Prosečan cc: 0.054958007866188964
# Lokalni stepeni klasterisanja koji nisu nula:
# 104925     Novak           Djokovic        (1) => 0.100789
# 103819     Roger           Federer         (5) => 0.100090
# 105577     Vasek           Pospisil        (61) => 0.092042
# 105676     David           Goffin          (15) => 0.089279
# 104731     Kevin           Anderson        (81) => 0.087469
# 104745     Rafael          Nadal           (2) => 0.086125
# 100644     Alexander       Zverev          (7) => 0.084252
# 105777     Grigor          Dimitrov        (19) => 0.083734
# 106421     Daniil          Medvedev        (4) => 0.083558
# 126774     Stefanos        Tsitsipas       (6) => 0.083467
# 106432     Borna           Coric           (24) => 0.083401
# 104871     Jeremy          Chardy          (75) => 0.083371
# 133430     Denis           Shapovalov      (12) => 0.080360
# 106233     Dominic         Thiem           (3) => 0.080124
# 104607     Tomas           Berdych         (0) => 0.079655
# 106378     Kyle            Edmund          (48) => 0.077765
# 126094     Andrey          Rublev          (8) => 0.077263
# 105227     Marin           Cilic           (42) => 0.076830
# 103970     David           Ferrer          (0) => 0.073977
# 105453     Kei             Nishikori       (41) => 0.073968
# 105554     Daniel          Evans           (32) => 0.073824
# 105916     Marton          Fucsovics       (55) => 0.073542
# 106043     Diego Sebastian Schwartzman     (9) => 0.073434
# 105173     Adrian          Mannarino       (35) => 0.072553
# 104542     Jo Wilfried     Tsonga          (62) => 0.072123
# 105732     Pierre Hugues   Herbert         (83) => 0.072060
# 200000     Felix           Auger Aliassime (21) => 0.071721
# 132283     Lorenzo         Sonego          (33) => 0.071641
# 200615     Alexei          Popyrin         (113) => 0.071295
# 104527     Stanislas       Wawrinka        (18) => 0.071057
# 128034     Hubert          Hurkacz         (34) => 0.070986
# 200282     Alex            De Minaur       (23) => 0.070731
# 106401     Nick            Kyrgios         (45) => 0.070327
# 105357     John            Millman         (38) => 0.069520
# 104545     John            Isner           (25) => 0.069381
# 105376     Peter           Gojowczyk       (145) => 0.068714
# 106065     Marco           Cecchinato      (80) => 0.068268
# 105138     Roberto         Bautista Agut   (13) => 0.068051
# 124187     Reilly          Opelka          (39) => 0.067347
# 105023     Sam             Querrey         (53) => 0.066935
# 103852     Feliciano       Lopez           (64) => 0.066909
# 106415     Yoshihito       Nishioka        (56) => 0.066537
# 105807     Pablo           Carreno Busta   (16) => 0.066478
# 126207     Francis         Tiafoe          (59) => 0.066280
# 104312     Andreas         Seppi           (106) => 0.066061
# 105062     Mikhail         Kukushkin       (89) => 0.066059
# 104792     Gael            Monfils         (11) => 0.065928
# 105936     Filip           Krajinovic      (31) => 0.065903
# 111577     Jared           Donaldson       (743) => 0.065645
# 105583     Dusan           Lajovic         (26) => 0.065622
# 111575     Karen           Khachanov       (20) => 0.065493
# 105332     Benoit          Paire           (28) => 0.065478
# 200175     Miomir          Kecmanovic      (44) => 0.065145
# 106426     Christian       Garin           (22) => 0.064843
# 206173     Jannik          Sinner          (37) => 0.064716
# 104269     Fernando        Verdasco        (65) => 0.064624
# 106298     Lucas           Pouille         (70) => 0.063288
# 104755     Richard         Gasquet         (47) => 0.063025
# 126610     Matteo          Berrettini      (10) => 0.062674
# 126203     Taylor Harry    Fritz           (29) => 0.062483
# 111797     Nicolas         Jarry           (989) => 0.062402
# 105526     Jan Lennard     Struff          (36) => 0.062214
# 122330     Alexander       Bublik          (50) => 0.062108
# 105430     Radu            Albot           (93) => 0.062009
# 105373     Martin          Klizan          (151) => 0.061503
# 106045     Denis           Kudla           (114) => 0.061470
# 105379     Aljaz           Bedene          (58) => 0.061251
# 111456     Mackenzie       Mcdonald        (193) => 0.061009
# 105683     Milos           Raonic          (14) => 0.060969
# 104259     Philipp         Kohlschreiber   (98) => 0.060809
# 104926     Fabio           Fognini         (17) => 0.059950
# 111202     Hyeon           Chung           (161) => 0.059882
# 104919     Leonardo        Mayer           (135) => 0.059607
# 105932     Nikoloz         Basilashvili    (40) => 0.059576
# 105077     Albert          Ramos           (46) => 0.058346
# 105643     Federico        Delbonis        (82) => 0.058246
# 105550     Guido           Pella           (43) => 0.057798
# 104198     Guillermo       Garcia Lopez    (220) => 0.057462
# 144750     Lloyd George Muirhead Harris          (87) => 0.057435
# 104665     Pablo           Andujar         (60) => 0.057294
# 144719     Jaume           Munar           (110) => 0.056585
# 105449     Steve           Johnson         (72) => 0.056564
# 104468     Gilles          Simon           (63) => 0.055852
# 105051     Matthew         Ebden           (317) => 0.055169
# 104898     Robin           Haase           (197) => 0.054199
# 106000     Damir           Dzumhur         (119) => 0.053565
# 105216     Yuichi          Sugita          (102) => 0.053236
# 200005     Ugo             Humbert         (30) => 0.053165
# 111442     Jordan          Thompson        (51) => 0.052738
# 105575     Ricardas        Berankis        (69) => 0.052102
# 105815     Tennys          Sandgren        (49) => 0.052037
# 134770     Casper          Ruud            (27) => 0.051828
# 105341     Thomas          Fabbiano        (172) => 0.051589
# 105806     Mirza           Basic           (326) => 0.051269
# 144895     Corentin        Moutet          (77) => 0.051101
# 105311     Joao            Sousa           (90) => 0.050972
# 105539     Evgeny          Donskoy         (123) => 0.050770
# 105657     Marius          Copil           (216) => 0.050465
# 111513     Laslo           Djere           (57) => 0.050178
# 104797     Denis           Istomin         (184) => 0.049591
# 105882     Stefano         Travaglia       (74) => 0.049444
# 111815     Cameron         Norrie          (71) => 0.048789
# 125802     Ilya            Ivashka         (108) => 0.048360
# 105614     Bradley         Klahn           (149) => 0.048029
# 106228     Juan Ignacio    Londero         (79) => 0.046730
# 105208     Ernests         Gulbis          (181) => 0.046499
# 106099     Salvatore       Caruso          (76) => 0.046493
# 106148     Roberto         Carballes Baena (97) => 0.046268
# 106075     Jozef           Kovalik         (131) => 0.046073
# 106071     Bernard         Tomic           (226) => 0.045731
# 104999     Mischa          Zverev          (264) => 0.044916
# 104655     Pablo           Cuevas          (67) => 0.044445
# 109739     Maximilian      Marterer        (209) => 0.044378
# 105992     Ryan            Harrison        (478) => 0.044194
# 106058     Jack            Sock            (253) => 0.043922
# 106121     Taro            Daniel          (117) => 0.043395
# 110602     Dennis          Novak           (96) => 0.043247
# 103333     Ivo             Karlovic        (147) => 0.042553
# 106198     Hugo            Dellien         (111) => 0.040443
# 105432     Prajnesh        Gunneswaran     (129) => 0.039443
# 104291     Malek           Jaziri          (249) => 0.038884
# 103893     Paolo           Lorenzi         (146) => 0.038392
# 106329     Thiago          Monteiro        (84) => 0.038123
# 106210     Jiri            Vesely          (68) => 0.034618

# %% [markdown]
# 11.pitanje

# %%
dict_w = dict(G.degree(weight="weight"))
dict_not_w = dict(G.degree())
dict_players = dict()
for key, value in dict_w.items():
    
    weight_degree = value
    degree = dict_not_w[key]
    
    dict_players[key] = (degree, weight_degree, weight_degree/degree)
    
sorted_dict = dict(sorted(dict_players.items(), key=lambda kv: kv[1][2], reverse = True))

for key, value in sorted_dict.items():
    print('{0:8s} {1:15s} {2:15s} ({3:4d}) => {4}'.format(key, G.nodes[key]['first_name'], G.nodes[key]['last_name'], G.nodes[key]['rank'], value))
# Out:
# 104925   Novak           Djokovic        (   1) => (80, 180, 2.25)
# 126774   Stefanos        Tsitsipas       (   6) => (99, 196, 1.97979797979798)
# 100644   Alexander       Zverev          (   7) => (95, 183, 1.9263157894736842)
# 106233   Dominic         Thiem           (   3) => (92, 176, 1.9130434782608696)
# 106421   Daniil          Medvedev        (   4) => (97, 183, 1.8865979381443299)
# 104745   Rafael          Nadal           (   2) => (82, 151, 1.8414634146341464)
# 106043   Diego Sebastian Schwartzman     (   9) => (90, 165, 1.8333333333333333)
# 133430   Denis           Shapovalov      (  12) => (92, 161, 1.75)
# 105676   David           Goffin          (  15) => (75, 131, 1.7466666666666666)
# 103819   Roger           Federer         (   5) => (74, 129, 1.7432432432432432)
# 126094   Andrey          Rublev          (   8) => (90, 151, 1.6777777777777778)
# 104545   John            Isner           (  25) => (74, 122, 1.6486486486486487)
# 106432   Borna           Coric           (  24) => (84, 138, 1.6428571428571428)
# 105173   Adrian          Mannarino       (  35) => (86, 140, 1.627906976744186)
# 106065   Marco           Cecchinato      (  80) => (66, 106, 1.606060606060606)
# 104731   Kevin           Anderson        (  81) => (64, 102, 1.59375)
# 105916   Marton          Fucsovics       (  55) => (78, 124, 1.5897435897435896)
# 105332   Benoit          Paire           (  28) => (89, 141, 1.5842696629213484)
# 105807   Pablo           Carreno Busta   (  16) => (86, 136, 1.5813953488372092)
# 200282   Alex            De Minaur       (  23) => (81, 128, 1.5802469135802468)
# 105227   Marin           Cilic           (  42) => (85, 134, 1.576470588235294)
# 105077   Albert          Ramos           (  46) => (80, 126, 1.575)
# 105138   Roberto         Bautista Agut   (  13) => (93, 146, 1.5698924731182795)
# 106378   Kyle            Edmund          (  48) => (74, 116, 1.5675675675675675)
# 104871   Jeremy          Chardy          (  75) => (70, 109, 1.5571428571428572)
# 104527   Stanislas       Wawrinka        (  18) => (71, 110, 1.5492957746478873)
# 105777   Grigor          Dimitrov        (  19) => (74, 114, 1.5405405405405406)
# 111575   Karen           Khachanov       (  20) => (103, 158, 1.5339805825242718)
# 105526   Jan Lennard     Struff          (  36) => (93, 142, 1.5268817204301075)
# 105932   Nikoloz         Basilashvili    (  40) => (83, 126, 1.5180722891566265)
# 105550   Guido           Pella           (  43) => (84, 126, 1.5)
# 126203   Taylor Harry    Fritz           (  29) => (88, 131, 1.4886363636363635)
# 128034   Hubert          Hurkacz         (  34) => (64, 95, 1.484375)
# 104468   Gilles          Simon           (  63) => (91, 135, 1.4835164835164836)
# 104269   Fernando        Verdasco        (  65) => (86, 127, 1.4767441860465116)
# 105453   Kei             Nishikori       (  41) => (78, 114, 1.4615384615384615)
# 200000   Felix           Auger Aliassime (  21) => (79, 115, 1.4556962025316456)
# 105577   Vasek           Pospisil        (  61) => (42, 61, 1.4523809523809523)
# 104926   Fabio           Fognini         (  17) => (96, 139, 1.4479166666666667)
# 104755   Richard         Gasquet         (  47) => (79, 114, 1.4430379746835442)
# 105732   Pierre Hugues   Herbert         (  83) => (77, 111, 1.4415584415584415)
# 126610   Matteo          Berrettini      (  10) => (84, 121, 1.4404761904761905)
# 105936   Filip           Krajinovic      (  31) => (75, 108, 1.44)
# 105683   Milos           Raonic          (  14) => (82, 118, 1.4390243902439024)
# 126207   Francis         Tiafoe          (  59) => (83, 119, 1.4337349397590362)
# 111797   Nicolas         Jarry           ( 989) => (65, 93, 1.4307692307692308)
# 104312   Andreas         Seppi           ( 106) => (73, 104, 1.4246575342465753)
# 111513   Laslo           Djere           (  57) => (66, 94, 1.4242424242424243)
# 105223   Juan Martin     Del Potro       ( 157) => (52, 74, 1.4230769230769231)
# 106000   Damir           Dzumhur         ( 119) => (71, 101, 1.4225352112676057)
# 105357   John            Millman         (  38) => (83, 118, 1.4216867469879517)
# 103852   Feliciano       Lopez           (  64) => (62, 88, 1.4193548387096775)
# 105583   Dusan           Lajovic         (  26) => (89, 126, 1.4157303370786516)
# 132283   Lorenzo         Sonego          (  33) => (57, 80, 1.4035087719298245)
# 105643   Federico        Delbonis        (  82) => (60, 84, 1.4)
# 106298   Lucas           Pouille         (  70) => (63, 88, 1.3968253968253967)
# 104792   Gael            Monfils         (  11) => (94, 131, 1.3936170212765957)
# 106401   Nick            Kyrgios         (  45) => (61, 85, 1.3934426229508197)
# 105554   Daniel          Evans           (  32) => (52, 72, 1.3846153846153846)
# 111442   Jordan          Thompson        (  51) => (60, 83, 1.3833333333333333)
# 105430   Radu            Albot           (  93) => (81, 112, 1.382716049382716)
# 105379   Aljaz           Bedene          (  58) => (71, 98, 1.380281690140845)
# 124187   Reilly          Opelka          (  39) => (54, 74, 1.3703703703703705)
# 103970   David           Ferrer          (   0) => (30, 41, 1.3666666666666667)
# 105376   Peter           Gojowczyk       ( 145) => (61, 83, 1.360655737704918)
# 104898   Robin           Haase           ( 197) => (67, 91, 1.3582089552238805)
# 105023   Sam             Querrey         (  53) => (71, 96, 1.352112676056338)
# 104259   Philipp         Kohlschreiber   (  98) => (75, 101, 1.3466666666666667)
# 105062   Mikhail         Kukushkin       (  89) => (80, 107, 1.3375)
# 105217   Thiemo          De Bakker       ( 684) => (3, 4, 1.3333333333333333)
# 105311   Joao            Sousa           (  90) => (90, 120, 1.3333333333333333)
# 103565   Stephane        Robert          ( 897) => (3, 4, 1.3333333333333333)
# 106110   Filip           Horansky        ( 185) => (6, 8, 1.3333333333333333)
# 104919   Leonardo        Mayer           ( 135) => (67, 89, 1.328358208955224)
# 200175   Miomir          Kecmanovic      (  44) => (55, 73, 1.3272727272727274)
# 105815   Tennys          Sandgren        (  49) => (66, 87, 1.3181818181818181)
# 104918   Andy            Murray          ( 122) => (29, 38, 1.3103448275862069)
# 106426   Christian       Garin           (  22) => (68, 89, 1.3088235294117647)
# 111815   Cameron         Norrie          (  71) => (80, 104, 1.3)
# 106415   Yoshihito       Nishioka        (  56) => (67, 87, 1.2985074626865671)
# 144719   Jaume           Munar           ( 110) => (57, 74, 1.2982456140350878)
# 106148   Roberto         Carballes Baena (  97) => (65, 84, 1.2923076923076924)
# 104665   Pablo           Andujar         (  60) => (48, 62, 1.2916666666666667)
# 106058   Jack            Sock            ( 253) => (32, 41, 1.28125)
# 104655   Pablo           Cuevas          (  67) => (80, 102, 1.275)
# 104542   Jo Wilfried     Tsonga          (  62) => (52, 66, 1.2692307692307692)
# 106228   Juan Ignacio    Londero         (  79) => (50, 63, 1.26)
# 106045   Denis           Kudla           ( 114) => (47, 59, 1.2553191489361701)
# 134770   Casper          Ruud            (  27) => (71, 89, 1.2535211267605635)
# 105449   Steve           Johnson         (  72) => (80, 100, 1.25)
# 105575   Ricardas        Berankis        (  69) => (48, 60, 1.25)
# 105373   Martin          Klizan          ( 151) => (49, 61, 1.2448979591836735)
# 111577   Jared           Donaldson       ( 743) => (29, 36, 1.2413793103448276)
# 206173   Jannik          Sinner          (  37) => (38, 47, 1.236842105263158)
# 103893   Paolo           Lorenzi         ( 146) => (34, 42, 1.2352941176470589)
# 122330   Alexander       Bublik          (  50) => (53, 65, 1.2264150943396226)
# 105065   Tim             Smyczek         ( 507) => (18, 22, 1.2222222222222223)
# 125802   Ilya            Ivashka         ( 108) => (41, 50, 1.2195121951219512)
# 144895   Corentin        Moutet          (  77) => (41, 50, 1.2195121951219512)
# 105657   Marius          Copil           ( 216) => (56, 68, 1.2142857142857142)
# 104999   Mischa          Zverev          ( 264) => (55, 66, 1.2)
# 123921   Calvin          Hemery          ( 468) => (5, 6, 1.2)
# 106398   Pedro           Cachin          ( 368) => (5, 6, 1.2)
# 200615   Alexei          Popyrin         ( 113) => (36, 43, 1.1944444444444444)
# 105051   Matthew         Ebden           ( 317) => (52, 62, 1.1923076923076923)
# 111456   Mackenzie       Mcdonald        ( 193) => (48, 56, 1.1666666666666667)
# 105341   Thomas          Fabbiano        ( 172) => (42, 49, 1.1666666666666667)
# 105413   Andrej          Martin          ( 101) => (18, 21, 1.1666666666666667)
# 106296   Gregoire        Barrere         ( 109) => (25, 29, 1.16)
# 200005   Ugo             Humbert         (  30) => (63, 73, 1.1587301587301588)
# 105992   Ryan            Harrison        ( 478) => (48, 55, 1.1458333333333333)
# 106329   Thiago          Monteiro        (  84) => (48, 55, 1.1458333333333333)
# 110602   Dennis          Novak           (  96) => (35, 40, 1.1428571428571428)
# 104467   Lamine          Ouahab          ( 648) => (7, 8, 1.1428571428571428)
# 105656   Marcelo         Arevalo         ( 447) => (7, 8, 1.1428571428571428)
# 106198   Hugo            Dellien         ( 111) => (35, 40, 1.1428571428571428)
# 200221   Alejandro       Davidovich Fokina (  52) => (29, 33, 1.1379310344827587)
# 104547   Horacio         Zeballos        (   0) => (22, 25, 1.1363636363636365)
# 105539   Evgeny          Donskoy         ( 123) => (44, 50, 1.1363636363636365)
# 104022   Mikhail         Youzhny         (   0) => (22, 25, 1.1363636363636365)
# 104797   Denis           Istomin         ( 184) => (46, 52, 1.1304347826086956)
# 111202   Hyeon           Chung           ( 161) => (54, 61, 1.1296296296296295)
# 133975   Benjamin        Hassan          ( 367) => (8, 9, 1.125)
# 106099   Salvatore       Caruso          (  76) => (32, 36, 1.125)
# 104122   Carlos          Berlocq         ( 505) => (8, 9, 1.125)
# 104297   Rogerio         Dutra Silva     ( 449) => (16, 18, 1.125)
# 106397   Wishaya         Trongcharoenchaikul ( 644) => (8, 9, 1.125)
# 104198   Guillermo       Garcia Lopez    ( 220) => (49, 55, 1.1224489795918366)
# 106078   Egor            Gerasimov       (  78) => (41, 46, 1.1219512195121952)
# 103333   Ivo             Karlovic        ( 147) => (52, 58, 1.1153846153846154)
# 105819   Guido           Andreozzi       ( 163) => (26, 29, 1.1153846153846154)
# 105806   Mirza           Basic           ( 326) => (35, 39, 1.1142857142857143)
# 104629   Adrian          Menendez Maceiras ( 265) => (9, 10, 1.1111111111111112)
# 105238   Alexandr        Dolgopolov      (   0) => (9, 10, 1.1111111111111112)
# 103607   Victor          Estrella        ( 892) => (9, 10, 1.1111111111111112)
# 144750   Lloyd George Muirhead Harris          (  87) => (45, 50, 1.1111111111111112)
# 106044   Nicolas         Kicker          (   0) => (18, 20, 1.1111111111111112)
# 106075   Jozef           Kovalik         ( 131) => (27, 30, 1.1111111111111112)
# 200514   Jurij           Rodionov        ( 144) => (9, 10, 1.1111111111111112)
# 106121   Taro            Daniel          ( 117) => (64, 71, 1.109375)
# 105041   Lukas           Lacko           ( 200) => (28, 31, 1.1071428571428572)
# 105432   Prajnesh        Gunneswaran     ( 129) => (28, 31, 1.1071428571428572)
# 106210   Jiri            Vesely          (  68) => (66, 73, 1.106060606060606)
# 124079   Pedro           Martinez Portero (  85) => (19, 21, 1.105263157894737)
# 105614   Bradley         Klahn           ( 149) => (29, 32, 1.103448275862069)
# 105208   Ernests         Gulbis          ( 181) => (40, 44, 1.1)
# 104607   Tomas           Berdych         (   0) => (41, 45, 1.0975609756097562)
# 104660   Sergiy          Stakhovsky      ( 202) => (21, 23, 1.0952380952380953)
# 111200   Elias           Ymer            ( 205) => (21, 23, 1.0952380952380953)
# 104291   Malek           Jaziri          ( 249) => (65, 71, 1.0923076923076922)
# 105882   Stefano         Travaglia       (  74) => (35, 38, 1.0857142857142856)
# 105132   Jurgen          Zopp            ( 565) => (12, 13, 1.0833333333333333)
# 105477   Marco           Trungelliti     ( 241) => (13, 14, 1.0769230769230769)
# 124014   Ernesto         Escobedo        ( 198) => (13, 14, 1.0769230769230769)
# 106026   Yuki            Bhambri         (   0) => (13, 14, 1.0769230769230769)
# 104719   Marcel          Granollers      ( 175) => (27, 29, 1.0740740740740742)
# 111511   Noah            Rubin           ( 250) => (14, 15, 1.0714285714285714)
# 109739   Maximilian      Marterer        ( 209) => (56, 60, 1.0714285714285714)
# 126156   Antonie         Hoang           ( 121) => (14, 15, 1.0714285714285714)
# 126952   Soon Woo        Kwon            (  95) => (29, 31, 1.0689655172413792)
# 104897   Matthias        Bachinger       ( 278) => (15, 16, 1.0666666666666667)
# 144707   Mikael          Ymer            (  94) => (30, 32, 1.0666666666666667)
# 105948   Federico        Coria           (  91) => (15, 16, 1.0666666666666667)
# 106034   Yasutaka        Uchiyama        ( 104) => (15, 16, 1.0666666666666667)
# 105216   Yuichi          Sugita          ( 102) => (46, 49, 1.065217391304348)
# 105385   Donald          Young           ( 323) => (16, 17, 1.0625)
# 106216   Bjorn           Fratangelo      ( 274) => (16, 17, 1.0625)
# 105487   Facundo         Bagnis          ( 125) => (17, 18, 1.0588235294117647)
# 104386   Janko           Tipsarevic      ( 263) => (17, 18, 1.0588235294117647)
# 126205   Tommy           Paul            (  54) => (36, 38, 1.0555555555555556)
# 105155   Pedro           Sousa           ( 105) => (20, 21, 1.05)
# 111581   Michael         Mmoh            ( 174) => (20, 21, 1.05)
# 103917   Nicolas         Mahut           ( 238) => (20, 21, 1.05)
# 106109   Alex            Bolt            ( 171) => (20, 21, 1.05)
# 105359   Jason           Jung            ( 132) => (22, 23, 1.0454545454545454)
# 105902   James           Duckworth       ( 103) => (22, 23, 1.0454545454545454)
# 120424   Yannick         Maden           ( 173) => (22, 23, 1.0454545454545454)
# 106368   Ramkumar        Ramanathan      ( 190) => (22, 23, 1.0454545454545454)
# 105226   Attila          Balazs          (  92) => (23, 24, 1.0434782608695652)
# 105613   Norbert         Gombos          (  88) => (23, 24, 1.0434782608695652)
# 105649   Cedrik Marcel   Stebe           ( 126) => (23, 24, 1.0434782608695652)
# 136440   Dominik         Koepfer         (  66) => (23, 24, 1.0434782608695652)
# 106218   Marcos          Giron           (  73) => (23, 24, 1.0434782608695652)
# 105074   Ruben           Bemelmans       ( 227) => (25, 26, 1.04)
# 104180   Gilles          Muller          (   0) => (27, 28, 1.037037037037037)
# 104678   Viktor          Troicki         ( 201) => (30, 31, 1.0333333333333334)
# 104571   Marcos          Baghdatis       ( 179) => (35, 36, 1.0285714285714285)
# 105967   Henri           Laaksonen       ( 134) => (37, 38, 1.027027027027027)
# 106071   Bernard         Tomic           ( 226) => (38, 39, 1.0263157894736843)
# 200711   Nicolas         Mejia           ( 457) => (1, 1, 1.0)
# 104460   Dustin          Brown           ( 261) => (7, 7, 1.0)
# 208937   Kasidit         Samrej          (1030) => (1, 1, 1.0)
# 104494   Adrian          Ungur           (   0) => (3, 3, 1.0)
# 206909   Brandon         Nakashima       ( 166) => (5, 5, 1.0)
# 104534   Dudi            Sela            ( 233) => (18, 18, 1.0)
# 110686   Finn            Tearney         (1042) => (1, 1, 1.0)
# 104563   Luca            Vanni           ( 451) => (2, 2, 1.0)
# 104586   Lukas           Rosol           ( 199) => (13, 13, 1.0)
# 104593   Daniel          Gimeno Traver   ( 442) => (1, 1, 1.0)
# 104597   Nicolas         Almagro         (   0) => (1, 1, 1.0)
# 110748   Nikola          Milojevic       ( 138) => (6, 6, 1.0)
# 127143   Jirat           Navasirisomboon (1586) => (4, 4, 1.0)
# 104620   Simone          Bolelli         ( 506) => (13, 13, 1.0)
# 133297   Yosuke          Watanuki        ( 251) => (5, 5, 1.0)
# 127157   Daniel          Altmaier        ( 130) => (7, 7, 1.0)
# 209080   Blaise          Bicknell        (1361) => (2, 2, 1.0)
# 110778   Joao Lucas      Magalhaes Hueb De Menezes ( 194) => (1, 1, 1.0)
# 208043   Ismael Changawa Ruwa Mzai            (   0) => (1, 1, 1.0)
# 108739   Wilfredo        Gonzalez        (1123) => (5, 5, 1.0)
# 104656   Haydn           Lewis           (   0) => (3, 3, 1.0)
# 108763   Alberto Emmanuel Alvarado Larin  (   0) => (3, 3, 1.0)
# 209119   Aissa           Benchakroun     (1722) => (1, 1, 1.0)
# 104672   Vincent         Millot          ( 957) => (2, 2, 1.0)
# 108772   Julius          Tverijonas      ( 830) => (1, 1, 1.0)
# 207134   Fitriadi        M Rifqi         (   0) => (1, 1, 1.0)
# 104735   Tobias          Kamke           ( 236) => (1, 1, 1.0)
# 207139   Palaphoom       Kovapitukted    (1053) => (4, 4, 1.0)
# 209188   Ari             Fahresi         (   0) => (1, 1, 1.0)
# 127300   Djurabek        Karimov         ( 605) => (2, 2, 1.0)
# 207176   Muhammad        Althaf Dhaifullah (   0) => (1, 1, 1.0)
# 209225   Martin Antonio  Vergara Del Puerto (   0) => (1, 1, 1.0)
# 209226   Adolfo Daniel   Vallejo         (   0) => (3, 3, 1.0)
# 207182   Emilio          Nava            ( 665) => (1, 1, 1.0)
# 209238   Sebastian       Dominguez       (   0) => (1, 1, 1.0)
# 127326   Ben             Fatael          ( 578) => (1, 1, 1.0)
# 104804   Amir            Weintraub       (   0) => (1, 1, 1.0)
# 104810   Zhe             Li              ( 234) => (8, 8, 1.0)
# 127339   Borna           Gojo            ( 221) => (4, 4, 1.0)
# 104868   James           Ward            ( 291) => (3, 3, 1.0)
# 104882   Blaz            Kavcic          ( 269) => (11, 11, 1.0)
# 104890   Andreas         Haider Maurer   (   0) => (9, 9, 1.0)
# 104901   Vladimir        Ivanov          ( 710) => (1, 1, 1.0)
# 104907   Jose Rubin      Statham         ( 769) => (5, 5, 1.0)
# 104932   Kenny           De Schepper     ( 669) => (2, 2, 1.0)
# 104947   Marsel          Ilhan           ( 575) => (1, 1, 1.0)
# 109054   Daniel          Masur           ( 245) => (3, 3, 1.0)
# 104970   Matteo          Viola           ( 222) => (2, 2, 1.0)
# 104978   Daniel          Brands          ( 723) => (3, 3, 1.0)
# 207400   Mark            Chigaazira      (   0) => (1, 1, 1.0)
# 207401   Sheil           Kotecha         (1422) => (1, 1, 1.0)
# 111153   Christopher     Eubanks         ( 235) => (10, 10, 1.0)
# 105011   Illya           Marchenko       ( 215) => (5, 5, 1.0)
# 105015   Franco          Skugor          ( 762) => (7, 7, 1.0)
# 207415   Daniel          Michalski       ( 428) => (1, 1, 1.0)
# 207421   Alex            Fairbanks       (   0) => (1, 1, 1.0)
# 111167   Ugo             Nastasi         (   0) => (2, 2, 1.0)
# 121411   Moez            Chargui         ( 779) => (1, 1, 1.0)
# 105030   Michael         Venus           (   0) => (3, 3, 1.0)
# 127570   Rodrigo         Arus            (   0) => (1, 1, 1.0)
# 111190   Zhizhen         Zhang           ( 164) => (7, 7, 1.0)
# 111192   Lucas           Miedler         ( 306) => (2, 2, 1.0)
# 105053   Santiago        Giraldo         ( 318) => (10, 10, 1.0)
# 111197   Jonathan        Mridha          ( 577) => (2, 2, 1.0)
# 105063   Andrea          Arnaboldi       ( 268) => (3, 3, 1.0)
# 105064   Thomaz          Bellucci        ( 281) => (6, 6, 1.0)
# 117353   Duck Hee        Lee             ( 275) => (2, 2, 1.0)
# 117356   Cem             Ilkel           ( 219) => (11, 11, 1.0)
# 117360   Marc            Polmans         ( 124) => (9, 9, 1.0)
# 207479   Soufiane        El Mesbahi      (   0) => (1, 1, 1.0)
# 105085   Artem           Smirnov         ( 692) => (2, 2, 1.0)
# 105091   Peter           Torebko         ( 353) => (1, 1, 1.0)
# 105111   Ivan            Endara          (1546) => (1, 1, 1.0)
# 207518   Lorenzo         Musetti         ( 128) => (8, 8, 1.0)
# 105147   Tatsuma         Ito             ( 186) => (6, 6, 1.0)
# 121531   Mats            Moraing         ( 247) => (1, 1, 1.0)
# 105156   Federico        Zeballos        ( 572) => (4, 4, 1.0)
# 105163   Gleb            Sakharov        ( 597) => (2, 2, 1.0)
# 105166   Peter           Polansky        ( 218) => (17, 17, 1.0)
# 207608   Timofey         Skatov          ( 445) => (1, 1, 1.0)
# 105254   Nikola          Mektic          (   0) => (1, 1, 1.0)
# 207669   Robert          Strombachs      ( 668) => (1, 1, 1.0)
# 105273   Mauricio        Echazu          ( 584) => (1, 1, 1.0)
# 207680   Facundo         Diaz Acosta     ( 403) => (1, 1, 1.0)
# 105292   Alejandro       Gonzalez        ( 448) => (4, 4, 1.0)
# 105299   Dzmitry         Zhyrmont        (   0) => (1, 1, 1.0)
# 133979   Hasan           Ibrahim         (1546) => (1, 1, 1.0)
# 111453   Mikael          Torpegaard      ( 189) => (2, 2, 1.0)
# 111459   Arjun           Kadhe           ( 662) => (3, 3, 1.0)
# 111460   Quentin         Halys           ( 203) => (8, 8, 1.0)
# 123755   Daniel Elahi    Galan Riveros   ( 115) => (20, 20, 1.0)
# 131951   Daniel          Cukierman       ( 783) => (2, 2, 1.0)
# 105334   Luis David      Martinez        (   0) => (3, 3, 1.0)
# 123768   Collin          Altamirano      ( 395) => (1, 1, 1.0)
# 207738   Brandon         Perez           (1722) => (2, 2, 1.0)
# 105339   Yan             Bai             ( 256) => (2, 2, 1.0)
# 205695   Ching           Lam             (   0) => (1, 1, 1.0)
# 105349   Harri           Heliovaara      ( 635) => (8, 8, 1.0)
# 111505   Enzo            Couacaud        ( 211) => (1, 1, 1.0)
# 125842   Adam            Moundir         ( 498) => (2, 2, 1.0)
# 123795   Altug           Celikbilek      ( 310) => (6, 6, 1.0)
# 111515   Thai Son        Kwiatkowski     ( 212) => (3, 3, 1.0)
# 205734   Thiago          Seyboth Wild    ( 116) => (14, 14, 1.0)
# 207797   Jonas           Forejtek        ( 361) => (4, 4, 1.0)
# 105406   Roberto         Marcora         ( 180) => (3, 3, 1.0)
# 209866   Karlis          Ozolins         (1073) => (1, 1, 1.0)
# 209867   Daniil          Ostapenkov      (   0) => (1, 1, 1.0)
# 209868   Kaipo           Marshall        (   0) => (1, 1, 1.0)
# 209869   Rodrigo         Crespo Piedra   (   0) => (1, 1, 1.0)
# 209870   Gunawan         Trismuwantara   (   0) => (1, 1, 1.0)
# 209871   Amr Elsayed Abdou Ahmed Mohamed         (   0) => (1, 1, 1.0)
# 209872   Thehan Sanjaya  Wijemanne       (   0) => (1, 1, 1.0)
# 209873   Eric Jr.        Olivarez        (   0) => (1, 1, 1.0)
# 209874   Maks            Kasnikowski     (   0) => (1, 1, 1.0)
# 111576   Sumit           Nagal           ( 136) => (10, 10, 1.0)
# 111578   Stefan          Kozlov          ( 370) => (2, 2, 1.0)
# 105436   Markus          Eriksson        ( 332) => (3, 3, 1.0)
# 207836   Muzammil        Murtaza         (   0) => (1, 1, 1.0)
# 111574   Jc              Aragone         ( 297) => (2, 2, 1.0)
# 105434   Ruan            Roelofse        ( 640) => (2, 2, 1.0)
# 105441   John Patrick    Smith           ( 313) => (5, 5, 1.0)
# 134114   Jad             Ballout         (   0) => (1, 1, 1.0)
# 134120   Kuan Yi         Lee             ( 753) => (1, 1, 1.0)
# 207852   Wai Yu          Kai             (   0) => (2, 2, 1.0)
# 105464   Christopher     Rungkat         (   0) => (1, 1, 1.0)
# 105467   Jordi           Munoz Abreu     (1265) => (2, 2, 1.0)
# 105479   Alejandro       Mendoza         ( 825) => (1, 1, 1.0)
# 105493   Tomislav        Brkic           ( 615) => (3, 3, 1.0)
# 105497   Jose            Hernandez       ( 316) => (6, 6, 1.0)
# 105499   Christopher     Diaz Figueroa   (   0) => (2, 2, 1.0)
# 105502   N Sriram        Balaji          (1164) => (1, 1, 1.0)
# 121896   Gabor           Borsos          (1285) => (1, 1, 1.0)
# 105515   Jordi           Samper Montana  (1042) => (1, 1, 1.0)
# 109640   Andrea          Basso           ( 591) => (1, 1, 1.0)
# 134217   Skyler          Butts           (1621) => (1, 1, 1.0)
# 103499   Aqeel           Khan            (   0) => (4, 4, 1.0)
# 123983   Nerman          Fatic           ( 373) => (1, 1, 1.0)
# 105561   Alessandro      Giannessi       ( 167) => (5, 5, 1.0)
# 105566   Shahin          Khaledan        (1722) => (1, 1, 1.0)
# 207971   Xavier          Lawrence        (   0) => (1, 1, 1.0)
# 207972   Minjong         Park            (1519) => (1, 1, 1.0)
# 207973   Ainius          Sabaliauskas    (   0) => (1, 1, 1.0)
# 103529   Aisam Ul Haq    Qureshi         (   0) => (3, 3, 1.0)
# 105578   Cristian        Rodriguez       ( 495) => (1, 1, 1.0)
# 105585   Ze              Zhang           ( 417) => (6, 6, 1.0)
# 105587   Tom             Kocevar Desman  ( 728) => (1, 1, 1.0)
# 105589   Gerald          Melzer          (1104) => (10, 10, 1.0)
# 124022   Chun Hun        Wong            (   0) => (2, 2, 1.0)
# 207989   Carlos          Alcaraz Garfia  ( 141) => (2, 2, 1.0)
# 109698   Christoffer     Konigsfeldt     (   0) => (1, 1, 1.0)
# 109699   Julian          Lenz            ( 248) => (2, 2, 1.0)
# 208004   Harold          Mayot           ( 426) => (2, 2, 1.0)
# 105606   Mohsen          Hossein Zade    (   0) => (1, 1, 1.0)
# 111761   Benjamin        Lock            ( 441) => (6, 6, 1.0)
# 207830   Tomas           Machac          ( 195) => (1, 1, 1.0)
# 126102   Nicolae         Frunza          ( 787) => (1, 1, 1.0)
# 105626   Takanyi         Garanganga      ( 567) => (5, 5, 1.0)
# 208028   Francisco       Llanes          (   0) => (1, 1, 1.0)
# 208029   Holger Vitus Nodskov Rune            ( 472) => (5, 5, 1.0)
# 105633   Mohamed         Safwat          ( 154) => (13, 13, 1.0)
# 105634   Viktor          Galovic         ( 284) => (7, 7, 1.0)
# 126120   Nino            Serdarusic      ( 293) => (4, 4, 1.0)
# 105641   Blaz            Rola            ( 155) => (3, 3, 1.0)
# 126125   Maxime          Janvier         ( 210) => (5, 5, 1.0)
# 111790   Brayden         Schnur          ( 208) => (14, 14, 1.0)
# 206000   Michel          Saade           (   0) => (1, 1, 1.0)
# 111794   Kamil           Majchrzak       ( 107) => (19, 19, 1.0)
# 111795   Filippo         Baldi           ( 242) => (3, 3, 1.0)
# 126127   Benjamin        Bonzi           ( 165) => (5, 5, 1.0)
# 126128   Roman           Safiullin       ( 182) => (2, 2, 1.0)
# 208055   Ajeet           Rai             ( 949) => (3, 3, 1.0)
# 111805   Seong Chan      Hong            ( 548) => (1, 1, 1.0)
# 138431   Darko           Bojanovic       (1499) => (1, 1, 1.0)
# 105668   Jerzy           Janowicz        ( 503) => (1, 1, 1.0)
# 126149   Gianluca        Mager           ( 100) => (13, 13, 1.0)
# 105671   Gastao          Elias           ( 410) => (10, 10, 1.0)
# 124116   Sebastian       Ofner           ( 159) => (9, 9, 1.0)
# 105688   Manuel          Sanchez         ( 852) => (6, 6, 1.0)
# 105691   Scott           Griekspoor      ( 694) => (1, 1, 1.0)
# 122078   Dmitry          Popko           ( 170) => (4, 4, 1.0)
# 126174   Youssef         Hossam          ( 820) => (3, 3, 1.0)
# 124126   Sarp            Agabigun        ( 882) => (1, 1, 1.0)
# 208103   Jiri            Lehecka         ( 351) => (1, 1, 1.0)
# 105707   Nicolaas        Scholtz         (   0) => (2, 2, 1.0)
# 208108   Brian           Shi             (   0) => (1, 1, 1.0)
# 126190   Nicolas         Alvarez         ( 345) => (4, 4, 1.0)
# 124154   Sasi Kumar      Mukund          ( 300) => (1, 1, 1.0)
# 126204   Gerardo         Lopez Villasenor ( 549) => (6, 6, 1.0)
# 122109   Sanjar          Fayziev         ( 513) => (7, 7, 1.0)
# 105723   Andrey          Kuznetsov       ( 517) => (2, 2, 1.0)
# 144642   Marcelo Tomas   Barrios Vera    ( 254) => (3, 3, 1.0)
# 105731   Steven          Diez            ( 179) => (3, 3, 1.0)
# 144645   Zdenek          Kolar           ( 232) => (1, 1, 1.0)
# 126214   Alejandro       Tabilo          ( 169) => (6, 6, 1.0)
# 208134   Luca            Nardi           ( 785) => (1, 1, 1.0)
# 144650   Rhett           Purcell         ( 908) => (1, 1, 1.0)
# 201995   Cayetano        March           ( 680) => (1, 1, 1.0)
# 105747   Karim Mohamed   Maamoun         ( 391) => (6, 6, 1.0)
# 132374   Jesse           Flores          (1051) => (2, 2, 1.0)
# 124186   Alexandre       Muller          ( 207) => (1, 1, 1.0)
# 105757   Sandro          Ehrat           ( 377) => (4, 4, 1.0)
# 126237   Gian Marco      Moroni          ( 230) => (2, 2, 1.0)
# 126239   Arthur          Rinderknech     ( 178) => (1, 1, 1.0)
# 144687   Quinton         Vega            (   0) => (2, 2, 1.0)
# 202065   Petros          Tsitsipas       (1004) => (2, 2, 1.0)
# 105812   David           Agung Susanto   (1385) => (4, 4, 1.0)
# 200031   Lucas           Catarina        ( 423) => (2, 2, 1.0)
# 105827   Laurynas        Grigelis        ( 422) => (7, 7, 1.0)
# 103781   Jurgen          Melzer          (1345) => (3, 3, 1.0)
# 208230   Alibek          Kachmazov       ( 790) => (1, 1, 1.0)
# 202090   Adrian          Andreev         ( 561) => (3, 3, 1.0)
# 200045   Anthony         Susanto         (   0) => (1, 1, 1.0)
# 105841   Lorenzo         Giustino        ( 152) => (3, 3, 1.0)
# 105842   Di              Wu              ( 321) => (5, 5, 1.0)
# 202103   Francisco       Cerundolo       ( 139) => (2, 2, 1.0)
# 144760   Amine           Ahouda          (1639) => (4, 4, 1.0)
# 126328   Gabriel         Donev           ( 997) => (1, 1, 1.0)
# 206199   Kevin           Cheruiyot       (1800) => (1, 1, 1.0)
# 200059   Yibing          Wu              ( 890) => (9, 9, 1.0)
# 122236   Roman           Hassanov        (   0) => (1, 1, 1.0)
# 132482   Liam            Caruana         ( 438) => (4, 4, 1.0)
# 126340   Viktor          Durasovic       ( 340) => (6, 6, 1.0)
# 208260   Zachary         Svajda          ( 774) => (1, 1, 1.0)
# 144775   Linh Giang      Trinh           (   0) => (1, 1, 1.0)
# 144776   Christophe      Tholl           (   0) => (2, 2, 1.0)
# 202120   Rowland         Phillips        (1438) => (1, 1, 1.0)
# 200075   Yshai           Oliel           ( 412) => (1, 1, 1.0)
# 105870   Yannick         Hanfmann        (  99) => (19, 19, 1.0)
# 202130   Emil            Reinberg        (   0) => (1, 1, 1.0)
# 105877   Emilio          Gomez           ( 160) => (5, 5, 1.0)
# 200095   Nicola          Kuhn            ( 252) => (5, 5, 1.0)
# 144807   Kenneth         Raisma          ( 818) => (1, 1, 1.0)
# 105899   Martin          Cuevas          ( 484) => (6, 6, 1.0)
# 144817   Marc Andrea     Huesler         ( 148) => (12, 12, 1.0)
# 105906   Kevin           Krawietz        ( 647) => (2, 2, 1.0)
# 105905   Danilo          Petrovic        ( 142) => (4, 4, 1.0)
# 202165   Alberto         Lim             (   0) => (4, 4, 1.0)
# 144826   Aziz            Dougaz          ( 380) => (2, 2, 1.0)
# 122298   Botic           Van De Zandschulp ( 156) => (1, 1, 1.0)
# 144841   Christian       Sigsgaard       (   0) => (2, 2, 1.0)
# 105933   Roberto         Quiroz          ( 296) => (7, 7, 1.0)
# 105935   Duilio          Beretta         (   0) => (1, 1, 1.0)
# 202195   Maxime          Cressy          ( 168) => (2, 2, 1.0)
# 105943   Federico        Gaio            ( 137) => (6, 6, 1.0)
# 103898   Julien          Benneteau       (   0) => (19, 19, 1.0)
# 105952   Renzo           Olivo           ( 214) => (5, 5, 1.0)
# 202210   Edris           Fetisleam       (1747) => (1, 1, 1.0)
# 105954   Peter           Nagy            ( 555) => (1, 1, 1.0)
# 105960   Evan            King            ( 425) => (1, 1, 1.0)
# 105961   David           Souto           (   0) => (1, 1, 1.0)
# 105963   Arthur          De Greef        ( 335) => (1, 1, 1.0)
# 208364   Franco          Roncadelli      (   0) => (2, 2, 1.0)
# 200181   Amer            Naow            (   0) => (1, 1, 1.0)
# 105985   Darian          King            ( 285) => (7, 7, 1.0)
# 202246   Nikoloz         Davlianidze     (   0) => (1, 1, 1.0)
# 106005   Constant        Lestienne       ( 225) => (5, 5, 1.0)
# 202262   Filip Cristian  Jianu           ( 397) => (1, 1, 1.0)
# 134677   Juan            Borba           (   0) => (1, 1, 1.0)
# 202261   Otto            Virtanen        ( 610) => (2, 2, 1.0)
# 200218   Mate            Valkusz         ( 570) => (3, 3, 1.0)
# 144932   Kristjan        Tamm            ( 625) => (2, 2, 1.0)
# 106021   Dragos          Dima            ( 766) => (2, 2, 1.0)
# 126502   Luis Diego      Chavez Villalpando (1217) => (1, 1, 1.0)
# 126504   Andrea          Pellegrino      ( 279) => (2, 2, 1.0)
# 106031   Raymond         Sarmiento       ( 401) => (1, 1, 1.0)
# 106032   Facundo         Arguello        ( 356) => (1, 1, 1.0)
# 144946   Rayane          Roumane         ( 376) => (1, 1, 1.0)
# 103990   Tommy           Robredo         ( 224) => (3, 3, 1.0)
# 200247   Alexandar       Lazarov         ( 546) => (3, 3, 1.0)
# 200250   Mehluli Don Ayanda Sibanda         ( 775) => (3, 3, 1.0)
# 126526   Soren           Hess Olesen     (   0) => (2, 2, 1.0)
# 126523   Bernabe         Zapata Miralles ( 150) => (4, 4, 1.0)
# 202300   Phuong Van      Nguyen          (   0) => (1, 1, 1.0)
# 126530   Peter           Bothwell        ( 823) => (2, 2, 1.0)
# 126535   Carlos          Taberner        ( 143) => (6, 6, 1.0)
# 200265   Ulises          Blanch          ( 243) => (1, 1, 1.0)
# 200267   Zizou           Bergs           ( 437) => (1, 1, 1.0)
# 200273   Hady            Habib           ( 751) => (6, 6, 1.0)
# 200274   Alex            Diaz            (   0) => (1, 1, 1.0)
# 106072   Alexey          Vatutin         ( 246) => (6, 6, 1.0)
# 200278   Simon           Carr            ( 543) => (2, 2, 1.0)
# 144985   Ergi            Kirkin          ( 444) => (1, 1, 1.0)
# 138845   Anthony Jackie  Tang            (   0) => (1, 1, 1.0)
# 138846   Hong Kit Jack   Wong            ( 921) => (2, 2, 1.0)
# 126555   Tung Lin        Wu              ( 244) => (3, 3, 1.0)
# 144984   Artem           Dubrivnyy       ( 430) => (1, 1, 1.0)
# 208476   Kyle            Johnson         (   0) => (1, 1, 1.0)
# 200303   Pavel           Kotov           ( 272) => (1, 1, 1.0)
# 202358   Chun Hsin       Tseng           ( 280) => (6, 6, 1.0)
# 145016   Julian          Saborio         (   0) => (1, 1, 1.0)
# 106105   Guilherme       Clezar          ( 271) => (3, 3, 1.0)
# 106106   George          Tsivadze        ( 885) => (2, 2, 1.0)
# 200325   Emil            Ruusuvuori      (  86) => (23, 23, 1.0)
# 208518   Hazem           Naw             (   0) => (2, 2, 1.0)
# 106120   Ricardo         Ojeda Lara      ( 459) => (6, 6, 1.0)
# 202382   Simen Sunde     Bratholm        (   0) => (1, 1, 1.0)
# 200335   Felipe          Meligeni Rodrigues Alves ( 231) => (1, 1, 1.0)
# 202385   Jenson          Brooksby        ( 307) => (3, 3, 1.0)
# 126609   Patrik          Niklas Salminen ( 440) => (2, 2, 1.0)
# 126612   Alexander       Cozbinov        ( 761) => (3, 3, 1.0)
# 126613   Bogdan          Borza           (1201) => (1, 1, 1.0)
# 200343   David           Szintai         (1602) => (1, 1, 1.0)
# 106137   Tristan         Lamasine        ( 266) => (2, 2, 1.0)
# 106138   Yaraslau        Shyla           ( 986) => (1, 1, 1.0)
# 202400   Alastair        Gray            (1112) => (1, 1, 1.0)
# 122533   Nam Hoang       Ly              ( 705) => (1, 1, 1.0)
# 106150   Jeson           Patrombon       (1463) => (6, 6, 1.0)
# 200368   Jack Mingjie    Lin             (1345) => (1, 1, 1.0)
# 122548   Edan            Leshem          ( 372) => (5, 5, 1.0)
# 106167   Joris           De Loore        (   0) => (2, 2, 1.0)
# 126652   Jay             Clarke          ( 187) => (8, 8, 1.0)
# 106174   Gonzalo         Lama            ( 734) => (1, 1, 1.0)
# 106175   Ricardo         Rodriguez       ( 537) => (4, 4, 1.0)
# 200384   Hugo            Gaston          ( 162) => (7, 7, 1.0)
# 106177   Oriol           Roca Batalla    ( 327) => (2, 2, 1.0)
# 200390   Kacper          Zuk             ( 262) => (3, 3, 1.0)
# 126663   Juan Pablo      Ficovich        ( 206) => (1, 1, 1.0)
# 106186   Jason           Kubler          ( 259) => (6, 6, 1.0)
# 122570   Mubarak Shannan Zayid           (   0) => (1, 1, 1.0)
# 200401   Amir Hossein    Badi            (   0) => (1, 1, 1.0)
# 134868   Tallon          Griekspoor      ( 153) => (9, 9, 1.0)
# 208597   Chak Lam Coleman Wong            (1577) => (1, 1, 1.0)
# 106203   Pedro           Sakamoto        ( 290) => (1, 1, 1.0)
# 202462   Yasitha         De Silva        (   0) => (3, 3, 1.0)
# 134886   Sharmal         Dissanayake     (   0) => (2, 2, 1.0)
# 106214   Oscar           Otte            ( 140) => (11, 11, 1.0)
# 202475   Philip          Henning         (   0) => (1, 1, 1.0)
# 106220   Dimitar         Kuzmanov        ( 295) => (10, 10, 1.0)
# 106223   Aleksandre      Metreveli       ( 593) => (6, 6, 1.0)
# 106227   Ji Sung         Nam             ( 270) => (1, 1, 1.0)
# 200436   Zsombor         Piros           ( 436) => (5, 5, 1.0)
# 106232   Roberto         Cid             ( 228) => (5, 5, 1.0)
# 106234   Aslan           Karatsev        ( 112) => (5, 5, 1.0)
# 106247   Nik             Razborsek       ( 729) => (1, 1, 1.0)
# 206600   Zura            Tkemaladze      (   0) => (1, 1, 1.0)
# 106249   Joao            Domingues       ( 176) => (10, 10, 1.0)
# 106250   Luis            Patino          ( 974) => (5, 5, 1.0)
# 106252   Joao Pedro      Sorgi           ( 666) => (3, 3, 1.0)
# 200460   John Bryan Decasa Otico           (   0) => (4, 4, 1.0)
# 200483   Peter August    Anker           (   0) => (1, 1, 1.0)
# 200484   Rudolf          Molleker        ( 217) => (12, 12, 1.0)
# 104229   Yen Hsun        Lu              (1007) => (2, 2, 1.0)
# 104233   Frederik        Nielsen         (   0) => (4, 4, 1.0)
# 106281   Liam            Broady          ( 188) => (5, 5, 1.0)
# 106283   Mitchell        Krueger         ( 192) => (7, 7, 1.0)
# 122669   Juan Pablo      Varillas Patino Samudio ( 158) => (9, 9, 1.0)
# 206642   Yassir          Kilani          (1453) => (1, 1, 1.0)
# 106293   Kimmer          Coppejans       ( 177) => (8, 8, 1.0)
# 104251   Ti              Chen            (1173) => (1, 1, 1.0)
# 104252   Florian         Mayer           (   0) => (17, 17, 1.0)
# 137018   Ayed            Zatar           (   0) => (2, 2, 1.0)
# 106302   Andrew          Harris          ( 229) => (1, 1, 1.0)
# 132932   Franz           Luna Lavidalie  (   0) => (2, 2, 1.0)
# 200526   Juan            Lugo            (   0) => (1, 1, 1.0)
# 106324   Vaclav          Safranek        ( 342) => (2, 2, 1.0)
# 106325   Jabor           Al Mutawa       (   0) => (1, 1, 1.0)
# 106328   Christian       Harrison        ( 784) => (3, 3, 1.0)
# 106331   Christopher     Oconnell        ( 120) => (3, 3, 1.0)
# 106333   Julien          Cagnina         ( 936) => (1, 1, 1.0)
# 200553   Alen            Avidzba         ( 455) => (2, 2, 1.0)
# 106348   Evgeny          Karlovskiy      ( 258) => (1, 1, 1.0)
# 206703   Paul            Jubb            ( 532) => (2, 2, 1.0)
# 106353   Pedja           Krstin          ( 267) => (3, 3, 1.0)
# 104308   Michal          Przysiezny      (1346) => (1, 1, 1.0)
# 106361   Adam            Pavlasek        ( 402) => (3, 3, 1.0)
# 206716   Lukas           Hellum Lilleengen (1444) => (1, 1, 1.0)
# 126845   Max             Purcell         ( 239) => (2, 2, 1.0)
# 126846   Aleksandar      Vukic           ( 196) => (2, 2, 1.0)
# 200574   Alexander       Donski          ( 592) => (2, 2, 1.0)
# 104327   Steve           Darcis          ( 273) => (20, 20, 1.0)
# 106388   Pak Long        Yeung           ( 964) => (2, 2, 1.0)
# 106391   Adrian          Bodmer          (1032) => (2, 2, 1.0)
# 106393   Frederico       Ferreira Silva  ( 183) => (2, 2, 1.0)
# 133018   Michail         Pervolarakis    ( 456) => (3, 3, 1.0)
# 106396   Cheng Yu        Yu              ( 922) => (1, 1, 1.0)
# 206748   Giulio          Zeppieri        ( 324) => (1, 1, 1.0)
# 206750   Daniil          Glinka          ( 844) => (1, 1, 1.0)
# 200611   Elliot          Benchetrit      ( 223) => (6, 6, 1.0)
# 106408   Mario           Vilella Martinez ( 191) => (1, 1, 1.0)
# 106410   Jorge Brian     Panta Herreros  ( 523) => (1, 1, 1.0)
# 200619   Sebastian       Arcila          (   0) => (1, 1, 1.0)
# 200620   Ignacio         Garcia          (   0) => (4, 4, 1.0)
# 106412   Lucas           Gomez           (1026) => (6, 6, 1.0)
# 206768   Rafael Eduardo  Gonzalez Retana (   0) => (1, 1, 1.0)
# 200624   Sebastian       Korda           ( 118) => (7, 7, 1.0)
# 106423   Thanasi         Kokkinakis      ( 260) => (16, 16, 1.0)
# 110536   Kevin           King            ( 305) => (4, 4, 1.0)
# 120792   M Abid Ali Khan Akbar           (   0) => (1, 1, 1.0)
# 126939   Khumoun         Sultanov        ( 330) => (2, 2, 1.0)
# 200670   Jeffrey John    Wolf            ( 127) => (5, 5, 1.0)
# 104424   Go              Soeda           ( 133) => (8, 8, 1.0)
# 126964   Vitaliy         Sachko          ( 400) => (1, 1, 1.0)

# %% [markdown]
# 15. pitanje

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter

def plot_deg_frequency(G, weighted=False, xscale = "log", yscale = "log", title = ""):

    if weighted:
        degrees = G.degree(weight="weight")
    else:
        degrees = G.degree()
    _, deg_list = zip(*degrees)
    deg_counts = Counter(deg_list)        
    print(deg_counts)
    x, y = zip(*deg_counts.items())                                                      

      
    plt.subplots(figsize=(10, 8))
    # prep axes   
    if weighted:
        plt.xlabel('weighted degree')  
    else:
        plt.xlabel('degree')   
        
    plt.xscale(xscale)                                                                                                                
    plt.xlim(1, max(x))  

    plt.ylabel('frequency')                                                                                                          
    plt.yscale(yscale)                                                                                                                
    plt.ylim(1, max(y))                                                                                                             
    
    plt.title(title)
    
    plt.scatter(x, y, marker='.')                                                                                                    
    plt.show()

# %%
plot_deg_frequency(G)
# Out:
# Counter({1: 159, 2: 70, 3: 43, 5: 25, 6: 25, 4: 22, 7: 14, 9: 10, 8: 10, 13: 7, 10: 7, 22: 6, 80: 6, 20: 6, 23: 6, 35: 5, 71: 5, 52: 5, 48: 5, 29: 5, 18: 4, 74: 4, 41: 4, 17: 4, 14: 4, 66: 4, 16: 4, 19: 4, 30: 3, 27: 3, 64: 3, 11: 3, 15: 3, 67: 3, 12: 3, 86: 3, 90: 3, 83: 3, 84: 3, 65: 3, 75: 3, 21: 2, 82: 2, 79: 2, 92: 2, 46: 2, 55: 2, 28: 2, 54: 2, 25: 2, 93: 2, 60: 2, 89: 2, 42: 2, 49: 2, 61: 2, 81: 2, 78: 2, 56: 2, 57: 2, 36: 2, 63: 2, 38: 2, 32: 2, 91: 1, 95: 1, 94: 1, 70: 1, 96: 1, 40: 1, 85: 1, 103: 1, 44: 1, 88: 1, 77: 1, 26: 1, 45: 1, 62: 1, 34: 1, 53: 1, 37: 1, 47: 1, 50: 1, 99: 1, 73: 1, 97: 1, 68: 1})

# %%
plot_deg_frequency(G, weighted = True)
# Out:
# Counter({1: 159, 2: 70, 3: 41, 6: 26, 4: 24, 5: 23, 7: 12, 10: 11, 8: 10, 9: 9, 23: 7, 21: 6, 13: 5, 24: 5, 14: 5, 18: 4, 31: 4, 16: 4, 38: 4, 126: 4, 17: 4, 50: 4, 36: 3, 29: 3, 114: 3, 131: 3, 11: 3, 89: 3, 61: 3, 74: 3, 20: 3, 19: 3, 73: 3, 55: 3, 40: 2, 66: 2, 25: 2, 102: 2, 62: 2, 183: 2, 151: 2, 49: 2, 83: 2, 118: 2, 15: 2, 60: 2, 32: 2, 84: 2, 104: 2, 39: 2, 87: 2, 88: 2, 12: 2, 101: 2, 41: 2, 71: 2, 135: 1, 110: 1, 122: 1, 45: 1, 161: 1, 52: 1, 109: 1, 91: 1, 180: 1, 139: 1, 96: 1, 107: 1, 22: 1, 26: 1, 146: 1, 140: 1, 44: 1, 134: 1, 120: 1, 56: 1, 141: 1, 94: 1, 98: 1, 58: 1, 112: 1, 158: 1, 100: 1, 95: 1, 142: 1, 72: 1, 93: 1, 68: 1, 80: 1, 119: 1, 111: 1, 115: 1, 136: 1, 47: 1, 129: 1, 124: 1, 108: 1, 42: 1, 65: 1, 33: 1, 165: 1, 59: 1, 106: 1, 128: 1, 30: 1, 46: 1, 121: 1, 28: 1, 63: 1, 176: 1, 196: 1, 127: 1, 116: 1, 85: 1, 43: 1, 138: 1})

# %% [markdown]
# 20. pitanje

# %%
G_novak = nx.ego_graph(G, '104925')

G_nadal = nx.ego_graph(G, '104745')

G_federer = nx.ego_graph(G, '103819')


plot_deg_frequency(G_novak, title = "Ego graf Novaka Djokovica")
plot_deg_frequency(G_nadal, title = "Ego graf Rafaela Nadala")
plot_deg_frequency(G_federer, title = "Ego graf Rogera Federera")
# Out:
# Counter({40: 7, 41: 5, 37: 4, 51: 4, 43: 4, 28: 4, 33: 4, 39: 3, 34: 3, 26: 2, 14: 2, 31: 2, 11: 2, 8: 2, 5: 2, 42: 2, 36: 2, 23: 2, 30: 2, 48: 2, 27: 2, 50: 2, 44: 1, 80: 1, 7: 1, 29: 1, 15: 1, 18: 1, 16: 1, 3: 1, 47: 1, 2: 1, 9: 1, 4: 1, 20: 1, 17: 1, 52: 1, 45: 1, 46: 1})
# Counter({24: 5, 29: 5, 47: 4, 38: 4, 51: 4, 43: 3, 28: 3, 42: 3, 45: 3, 30: 3, 46: 3, 8: 3, 48: 3, 39: 2, 40: 2, 3: 2, 33: 2, 26: 2, 20: 2, 12: 2, 2: 1, 41: 1, 14: 1, 16: 1, 36: 1, 4: 1, 23: 1, 15: 1, 54: 1, 52: 1, 44: 1, 32: 1, 21: 1, 49: 1, 37: 1, 35: 1, 34: 1, 82: 1, 25: 1, 17: 1, 53: 1, 55: 1, 60: 1})
# Counter({41: 7, 42: 5, 46: 5, 48: 4, 35: 4, 47: 4, 39: 4, 32: 3, 37: 3, 45: 3, 27: 3, 51: 2, 38: 2, 28: 2, 50: 2, 36: 2, 8: 1, 4: 1, 52: 1, 33: 1, 74: 1, 26: 1, 11: 1, 31: 1, 21: 1, 34: 1, 20: 1, 29: 1, 3: 1, 30: 1, 14: 1, 44: 1, 43: 1, 23: 1, 40: 1, 6: 1})

# %% [markdown]
# 22.pitanje

# %% [markdown]
# a) Novak mega cvor

# %%
G_mega_novak = nx.Graph()
G.add_node('1', first_name = "Mega", last_name = "Node")

novak_nodes_list = list(G_novak.nodes)

for node in list(G.nodes(data=True)):
    if node[0] not in novak_nodes_list:
        G_mega_novak.add_node(node[0], first_name = node[1]["first_name"], last_name = node[1]["last_name"])

for edge in list(G.edges(data=True)):
    if edge[0] in novak_nodes_list:
        if ('1', edge[1]) in G_mega_novak.edges():
            G_mega_novak['1'][edge[1]]['weight'] += edge[2]["weight"]
        else:
            G_mega_novak.add_edge('1', edge[1], weight = edge[2]["weight"])
    elif edge[1] in novak_nodes_list:
        if ('1', edge[0]) in G_mega_novak.edges():
            G_mega_novak['1'][edge[0]]['weight'] += edge[2]["weight"]
        else:
            G_mega_novak.add_edge('1', edge[0], weight = edge[2]["weight"])
    else:
        G_mega_novak.add_edge(edge[0], edge[1], weight = edge[2]["weight"])

output_path = "models/novak_mega_node.gml"
nx.write_gml(G_mega_novak, output_path)

# %% [markdown]
# 23. pitanje

# %%
from networkx.algorithms import community

G_unija = nx.Graph()
G_unija.add_nodes_from(G_novak.nodes())
G_unija.add_nodes_from(G_nadal.nodes())
G_unija.add_nodes_from(G_federer.nodes())


for e in G_novak.edges():
    if e not in G_unija.edges():
        G_unija.add_edge(e[0], e[1], weight = (G_novak.get_edge_data(*e))['weight'])

for e in G_nadal.edges():
    if e not in G_unija.edges():
        G_unija.add_edge(e[0], e[1], weight = (G_nadal.get_edge_data(*e))['weight'])

for e in G_federer.edges():
    if e not in G_unija.edges():
        G_unija.add_edge(e[0], e[1], weight = (G_federer.get_edge_data(*e))['weight'])

output_path = "models/ego_mreze.gml"
nx.write_gml(G_unija, output_path)

print(nx.info(G_unija))

print(f"Procenat igraca koji pripadaju ovom grafu je {G_unija.number_of_nodes() * 100 / G.number_of_nodes()} %")

comp = community.girvan_newman(G_unija)
for c in next(comp):
    print(c)
# Out:
# Name:
# Type: Graph
# Number of nodes: 136
# Number of edges: 2563
# Average degree:  37.6912
# Procenat igraca koji pripadaju ovom grafu je 23.367697594501717 %
# {'105453', '106043', '106000', '106099', '200005', '104547', '127339', '105216', '105357', '104925', '104926', '104291', '104665', '123755', '126952', '104297', '103970', '105077', '105936', '132283', '105051', '105430', '104534', '106071', '105815', '106415', '106283', '105311', '105676', '105657', '144895', '200175', '200000', '103607', '105806', '106198', '104607', '105916', '105238', '105023', '133430', '105062', '105932', '105575', '105332', '106421', '128034', '105173', '105732', '104655', '105227', '104542', '103819', '105643', '104527', '111456', '106216', '105583', '126207', '104198', '106228', '106065', '105870', '105554', '104269', '105074', '106298', '104468', '104919', '105882', '105376', '105526', '200282', '104898', '105166', '103852', '109739', '105449', '106121', '104792', '104871', '105223', '105902', '120424', '144707', '105550', '106045', '105385', '105041', '106378', '105379', '104797', '104745', '106078', '126652', '111202', '144719', '111577', '104424', '104259', '105683', '200615', '106426', '144750', '104999', '106423', '105967', '100644', '105807', '126774', '134770', '106210', '136440', '111576', '111575', '105138', '126203', '106233', '105577', '104731', '106432', '126094', '200624', '126610', '104620', '104312', '106401', '104755', '104545', '206173', '111442', '106148', '105777', '105373', '106214'}
# {'105147'}

# %% [markdown]
# 25. pitanje

# %% [markdown]
# a)

# %%
dict_godina = dict()

dataPath = "data/atp_matches_2018.csv"
matches2018 = pd.read_csv(dataPath)

num2018 = matches2018.loc[~matches2018['tourney_id'].str.startswith("2018-M-DC"),'tourney_id'].agg(['nunique'])[0]

dataPath = "data/atp_matches_2019.csv"
matches2019 = pd.read_csv(dataPath)

num2019 = matches2019.loc[~matches2019['tourney_id'].str.startswith("2019-M-DC"),'tourney_id'].agg(['nunique'])[0]

dataPath = "data/atp_matches_2020.csv"
matches2020 = pd.read_csv(dataPath)

num2020 = matches2020.loc[~matches2020['tourney_id'].str.startswith("2020-M-DC"),'tourney_id'].agg(['nunique'])[0]

dict_godina["2018"] = num2018
dict_godina["2019"] = num2019
dict_godina["2020"] = num2020

godine = list(dict_godina.keys())
broj_turnira = list(dict_godina.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(godine, broj_turnira, color ='maroon',
        width = 0.4)
 
plt.xlabel("Godina odrzavanja")
plt.ylabel("Broj turnira")
plt.title("Distribucija broja turnira u odnosu na godinu odrzavanja")
plt.show()

# %% [markdown]
# b)

# %%
dict_surface = dict()

dataPath = "data/atp_matches_2018.csv"
matches2018 = pd.read_csv(dataPath)

mask2018 = ~matches2018['tourney_id'].str.startswith("2018-M-DC")
matches2018 = (matches2018[mask2018].groupby(['tourney_id','surface']).nunique().reset_index())[['tourney_id','surface']]
matches2018 = matches2018.groupby('surface').size().reset_index().rename(columns={0:'count'})

dataPath = "data/atp_matches_2019.csv"
matches2019 = pd.read_csv(dataPath)

mask2019 = ~matches2019['tourney_id'].str.startswith("2019-M-DC")
matches2019 = (matches2019[mask2019].groupby(['tourney_id','surface']).nunique().reset_index())[['tourney_id','surface']]
matches2019 = matches2019.groupby('surface').size().reset_index().rename(columns={0:'count'})

dataPath = "data/atp_matches_2020.csv"
matches2020 = pd.read_csv(dataPath)

mask2020 = ~matches2020['tourney_id'].str.startswith("2020-M-DC")
matches2020 = (matches2020[mask2020].groupby(['tourney_id','surface']).nunique().reset_index())[['tourney_id','surface']]
matches2020 = matches2020.groupby('surface').size().reset_index().rename(columns={0:'count'})

frames = [matches2018, matches2019, matches2020]

tourneys = pd.concat(frames)

for index, row in tourneys.iterrows():
    surface = row['surface']
    num = row['count']
    if surface in dict_surface:
        dict_surface[surface] += num
    else:
        dict_surface[surface] = num
        
podloge = list(dict_surface.keys())
broj_turnira = list(dict_surface.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(podloge, broj_turnira, color ='maroon',
        width = 0.4)
 
plt.xlabel("Podloga")
plt.ylabel("Broj turnira")
plt.title("Distribucija broja turnira u odnosu na podlogu")
plt.show()

# %% [markdown]
# 26. pitanje

# %% [markdown]
# a)

# %%
dict_years = dict()

dataPath = "data/atp_matches_2018.csv"
matches2018 = pd.read_csv(dataPath)

dict_years['2018'] = matches2018.shape[0]

dataPath = "data/atp_matches_2019.csv"
matches2019 = pd.read_csv(dataPath)

dict_years['2019'] = matches2019.shape[0]

dataPath = "data/atp_matches_2020.csv"
matches2020 = pd.read_csv(dataPath)

dict_years['2020'] = matches2020.shape[0]

godine = list(dict_years.keys())
broj_meceva = list(dict_years.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(godine, broj_meceva, color ='maroon',
        width = 0.4)
 
plt.xlabel("Godina")
plt.ylabel("Broj meceva")
plt.title("Distribucija broja meceva u odnosu na godinu odrzavanja")
plt.show()

# %% [markdown]
# b)

# %%
dict_surface = dict()

dataPath = "data/atp_matches_2018.csv"
matches2018 = pd.read_csv(dataPath)


matches2018 = matches2018.groupby(['surface']).size().reset_index().rename(columns={0:'count'})


dataPath = "data/atp_matches_2019.csv"
matches2019 = pd.read_csv(dataPath)

matches2019 = matches2019.groupby(['surface']).size().reset_index().rename(columns={0:'count'})

dataPath = "data/atp_matches_2020.csv"
matches2020 = pd.read_csv(dataPath)

matches2020 = matches2020.groupby(['surface']).size().reset_index().rename(columns={0:'count'})

frames = [matches2018, matches2019, matches2020]

tourneys = pd.concat(frames)

for index, row in tourneys.iterrows():
    surface = row['surface']
    num = row['count']
    if surface in dict_surface:
        dict_surface[surface] += num
    else:
        dict_surface[surface] = num
        
podloge = list(dict_surface.keys())
broj_meceva = list(dict_surface.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(podloge, broj_meceva, color ='maroon',
        width = 0.4)
 
plt.xlabel("Podloga")
plt.ylabel("Broj meceva")
plt.title("Distribucija broja meceva u odnosu na podlogu")
plt.show()
